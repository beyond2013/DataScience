# %% [markdown]
# # Titanic - Machine Learning from Disaster
#
# - The sinking of the Titanic is one of the most infamous shipwrecks in history.
# - While there was some element of luck involved in surviving
# - it seems **some groups of people were more likely to survive** than others.
#
# ## Challenge
# - build a predictive model that answers the question: _**what sorts of people were more likely to survive?**_
#
# ## Data
# - passenger data i.e. name, age, gender, socio-economic class, etc.
# - one data is titled train.csv and the other is titled test.csv

# %%
# import relevant libraries

import pandas as pd

# %%
train_data = pd.read_csv('workshop/dataset/titanic/train.csv')

# %%
train_data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
train_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_data[445:449]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 445          446         1       1          Dodge, Master. Washington    male
# 446          447         1       2  Mellinger, Miss. Madeleine Violet  female
# 447          448         1       1        Seward, Mr. Frederic Kimber    male
# 448          449         1       3     Baclini, Miss. Marie Catherine  female
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 445   4.0      0      2   33638  81.8583   A34        S
# 446  13.0      0      1  250644  19.5000   NaN        S
# 447  34.0      0      0  113794  26.5500   NaN        S
# 448   5.0      2      1    2666  19.2583   NaN        C

# %%
train_data.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
train_data[train_data['Age'] > 30]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_data[['Age','Sex']]
# Out:
#       Age     Sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 886  27.0    male
# 887  19.0  female
# 888   NaN  female
# 889  26.0    male
# 890  32.0    male
#
# [891 rows x 2 columns]
