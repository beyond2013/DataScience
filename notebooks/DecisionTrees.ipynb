# %%
import pandas as pd

# %%
train = pd.read_csv("./workshop/dataset/titanic/train.csv")
test = pd.read_csv("./workshop/dataset/titanic/test.csv")

# %%
# copy original train data

original_train = train.copy()

# %%
full_data = [train, test]

# %%
train[700:730]
# Out:
#      PassengerId  Survived  Pclass  \
# 700          701         1       1
# 701          702         1       1
# 702          703         0       3
# 703          704         0       3
# 704          705         0       3
# 705          706         0       2
# 706          707         1       2
# 707          708         1       1
# 708          709         1       1
# 709          710         1       3
# 710          711         1       1
# 711          712         0       1
# 712          713         1       1
# 713          714         0       3
# 714          715         0       2
# 715          716         0       3
# 716          717         1       1
# 717          718         1       2
# 718          719         0       3
# 719          720         0       3
# 720          721         1       2
# 721          722         0       3
# 722          723         0       2
# 723          724         0       2
# 724          725         1       1
# ...

# %%
train[["Name", "Age"]]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
train.groupby("Survived").count()
# Out:
#           PassengerId  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Survived
# 0                 549     549   549  549  424    549    549     549   549
# 1                 342     342   342  342  290    342    342     342   342
#
#           Cabin  Embarked
# Survived
# 0            68       549
# 1           136       340

# %%
import numpy 
pivot_table = train.pivot_table(train, values=['Survived'],
                                columns=['Sex'],
                                 aggfunc={'Survived': numpy.sum})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-c04c0c29b9e6> in <module>
#       1 import numpy
# ----> 2 pivot_table = train.pivot_table(train, values=['Survived'],
#       3                                 columns=['Sex'],
#       4                                  aggfunc={'Survived': numpy.sum})
#
# TypeError: pivot_table() got multiple values for argument 'values'
